# %%
import numpy as np
import pandas as pd
from PIL import Image

# %%
df = pd.read_csv('locate.csv', encoding='shift_jis')

# %%
df
# Out:
#     No               name       dai       name1                   yomi  \
# 0    1           001jinmu        初代       神武天皇陵             じんむてんのうりょう
# 1    2          002suizei       第2代       綏靖天皇陵            すいぜいてんのうりょう
# 2    3           003sujin      第10代       崇神天皇陵             すじんてんのうりょう
# 3    4          004keikou      第12代       景行天皇量            けいこうてんのうりょう
# 4    5           005oujin      第15代       応神天皇陵            おうじんてんのうりょう
# 5    6          006seinei      第22代       清寧天皇陵            せいねいてんのうりょう
# 6    7          007ninken      第24代       仁賢天皇陵            にんけんてんのうりょう
# 7    8           008ankan      第27代       安閑天皇陵            あんかんてんのうりょう
# 8    9          009bidatu      第30代       敏達天皇陵             びだつてんのうりょう
# 9   10          010youmei      第31代       用明天皇陵            ようめいてんのうりょう
# 10  11           011suiko      第33代       推古天皇陵             すいこてんのうりょう
# 11  12           012tenji      第38代       天智天皇陵             てんじてんのうりょう
# ...
